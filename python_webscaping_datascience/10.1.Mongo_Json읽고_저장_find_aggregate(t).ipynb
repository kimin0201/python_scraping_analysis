# %% [markdown]
# ### 1. MongoDB에 웹스크래핑 데이터 저장하기
# * MongoDB에 연결
# * database와 collection 생성
# * actors.json 읽어서 insert_many()

# %%
import pymongo
import json

con = pymongo.MongoClient(host='localhost',port=27017)
print(con)

db = con.member_db
print(db)

#collection drop 
db.drop_collection('actors')

col = db.actors
print(col)

with open('data/actors.json','r',encoding='utf8') as file:
    json_data = json.load(file)
    col.insert_many(json_data)

print('document 건수', col.estimated_document_count())
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'member_db')
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'member_db'), 'actors')
# document 건수 44

# %%
#컬렉션의 find()를 사용한 함수 정의
def print_find_document(criteria, projection):
    for idx, member_doc in enumerate(col.find(criteria, projection),1):
        print(idx, member_doc)

# %%
#컬렉션의 aggregate()를 사용한 함수 정의
def print_aggregate_document(*args):
    agg_list = []
    for arg in args:
        agg_list.append(arg)
    print(agg_list)
    
    for agg_doc in col.aggregate(agg_list):
        print(agg_doc)

# %%
#1. 랭킹 1 ~ 50 인 배우의 배우이름,랭킹,흥행지수,소속사,출연영화
criteria = {
    '랭킹':{'$lte':50}
}
projection = {
    '_id':0,'랭킹':1,'배우이름':1,'흥행지수':1,'소속사':1,'출연영화':1
}

print_find_document(criteria, projection)
# Out:
# 1 {'배우이름': '이병헌', '랭킹': 1, '흥행지수': '21472', '출연영화': ['비상선언', '콘크리트 유토피아', '백두산']}
# 2 {'배우이름': '진선규', '랭킹': 2, '흥행지수': '19105', '출연영화': ['카운트(가제)', '킹덤 시즌 2', '사바하']}
# 3 {'배우이름': '하정우', '랭킹': 3, '흥행지수': '17579', '출연영화': ['클로젯', '백두산', 'PMC: 더 벙커']}
# 4 {'배우이름': '마동석', '랭킹': 4, '흥행지수': '17337', '출연영화': ['시동', '나쁜 녀석들: 더 무비', '백두산']}
# 5 {'배우이름': '이하늬', '랭킹': 5, '흥행지수': '15912', '출연영화': ['블랙머니', '열혈사제', '극한직업']}
# 6 {'배우이름': '류승룡', '랭킹': 6, '흥행지수': '14030', '소속사': '필름있수다', '출연영화': ['휴머니멀', '킹덤 시즌 2', '입술은 안돼요(가제)']}
# 7 {'배우이름': '유해진', '랭킹': 7, '흥행지수': '13690', '소속사': '심엔터테인먼트', '출연영화': ['휴머니멀', '삼시세끼 어촌편 5', '봉오동 전투']}
# 8 {'배우이름': '박정민', '랭킹': 8, '흥행지수': '12976', '출연영화': ['사냥의 시간', '다만 악에서 구하소서', '사바하']}
# 9 {'배우이름': '황정민', '랭킹': 9, '흥행지수': '12863', '소속사': '예당엔터테인먼트', '출연영화': ['다만 악에서 구하소서', '교섭', '공작']}
# 10 {'배우이름': '송강호', '랭킹': 10, '흥행지수': '12429', '소속사': '호두엔터테인먼트', '출연영화': ['비상선언', '브로커(가제)', '기생충']}
# 11 {'배우이름': '조진웅', '랭킹': 11, '흥행지수': '11848', '소속사': '㈜사람엔터테인먼트', '출연영화': ['경관의 피(가제)', '대외비: 권력의 탄생(가제)', '광대들: 풍문조작단']}
# 12 {'배우이름': '신하균', '랭킹': 12, '흥행지수': '11173', '출연영화': ['영혼수선공', '선물', '미스터 주: 사라진 VIP']}
# 13 {'배우이름': '조우진', '랭킹': 13, '흥행지수': '10907', '출연영화': ['도굴', '서복', '봉오동 전투']}
# 14 {'배우이름': '이동휘', '랭킹': 14, '흥행지수': '10771', '출연영화': ['콜', '시네마틱드라마 SF8 -  만신', '시네마틱드라마 SF8']}
# 15 {'배우이름': '이정재', '랭킹': 15, '흥행지수': '10613', '소속사': '아티스트컴퍼니', '출연영화': ['다만 악에서 구하소서', '사바하', '보좌관 – 세상을 움직이는 사람들']}
# 16 {'배우이름': '전혜진', '랭킹': 16, '흥행지수': '10183', '소속사': '호두엔터테인먼트', '출연영화': ['비밀의 숲 2', '백두산', '검색어를 입력하세요 WWW']}
# 17 {'배우이름': '염정아', '랭킹': 17, '흥행지수': '9937', '소속사': '아티스트컴퍼니', '출연영화': ['시동', '강철비2: 정상회담', '인생은 아름다워']}
# 18 {'배우이름': '공명', '랭킹': 18, '흥행지수': '9635', '출연영화': ['한산: 용의 출현', '행복의 진수', '행복의 진수']}
# 19 {'배우이름': '장혜진', '랭킹': 19, '흥행지수': '9510', '출연영화': ['애비규환', '계약우정', '출사표']}
# 20 {'배우이름': '이선균', '랭킹': 20, '흥행지수': '9089', '소속사': '호두엔터테인먼트', '출연영화': ['기생충', '킹메이커', '미스터 주: 사라진 VIP']}
# 21 {'배우이름': '유아인', '랭킹': 21, '흥행지수': '8979', '출연영화': ['소리도 없이', '＃살아있다', '도올아인 오방간다']}
# 22 {'배우이름': '조정석', '랭킹': 22, '흥행지수': '8566', '출연영화': ['슬기로운 의사생활', '엑시트', '녹두꽃']}
# 23 {'배우이름': '오정세', '랭킹': 23, '흥행지수': '8377', '소속사': '스타파크엔터테인먼트', '출연영화': ['콜', '냐옹은 페이크다', '드라마 스테이지 - 남편한테 김희선이 생겼어요']}
# 24 {'배우이름': '이성민', '랭킹': 24, '흥행지수': '8338', '출연영화': ['대외비: 권력의 탄생(가제)', '머니게임', '미스터 주: 사라진 VIP']}
# 25 {'배우이름': '최우식', '랭킹': 25, '흥행지수': '8228', '출연영화': ['사냥의 시간', '경관의 피(가제)', '원더랜드']}
# 26 {'배우이름': '박소담', '랭킹': 26, '흥행지수': '7509', '소속사': '아티스트컴퍼니', '출연영화': ['제34회 골든디스크어워즈 with 틱톡', '청춘기록', '갬성캠핑']}
# 27 {'배우이름': '김윤석', '랭킹': 27, '흥행지수': '7279', '소속사': '심엔터테인먼트', '출연영화': ['바이러스(가제)', '암수살인', '미성년']}
# 28 {'배우이름': '공효진', '랭킹': 28, '흥행지수': '7275', '출연영화': ['동백꽃 필 무렵', '가장 보통의 연애', '뺑반']}
# 29 {'배우이름': '김의성', '랭킹': 29, '흥행지수': '7163', '소속사': '아티스트컴퍼니', '출연영화': ['나의 촛불', '특송', '국민 여러분!']}
# 30 {'배우이름': '김아중', '랭킹': 30, '흥행지수': '7136', '소속사': '예당엔터테인먼트', '출연영화': ['나쁜 녀석들: 더 무비', '비밀 기획단', '명불허전']}
# 31 {'배우이름': '김무열', '랭킹': 31, '흥행지수': '6729', '출연영화': ['침입자', '보이스(가제)', '대외비: 권력의 탄생(가제)']}
# 32 {'배우이름': '강기영', '랭킹': 32, '흥행지수': '6558', '출연영화': ['휴가', '교섭', '런']}
# 33 {'배우이름': '곽도원', '랭킹': 33, '흥행지수': '6447', '출연영화': ['소방관', '강철비2: 정상회담', '국제수사']}
# 34 {'배우이름': '성동일', '랭킹': 34, '흥행지수': '6354', '출연영화': ['담보', '방법', '어쩌다 가족']}
# 35 {'배우이름': '김종수', '랭킹': 35, '흥행지수': '6297', '소속사': '아티스트컴퍼니', '출연영화': ['드림 (가제)', '아버지가방에들어가신다!', '삼진그룹 영어토익반']}
# 36 {'배우이름': '배수지', '랭킹': 36, '흥행지수': '5933', '소속사': 'JYP엔터테인먼트', '출연영화': ['원더랜드', '제56회 백상예술대상', '스타트업']}
# 37 {'배우이름': '권해효', '랭킹': 37, '흥행지수': '5863', '출연영화': ['반도', '도망친 여자', '아무도 모른다']}
# 38 {'배우이름': '임윤아', '랭킹': 38, '흥행지수': '5791', '소속사': 'SM엔터테인먼트', '출연영화': ['엑시트', '효리네 민박 2', '소녀포레스트']}
# 39 {'배우이름': '주지훈', '랭킹': 39, '흥행지수': '5685', '출연영화': ['하이에나', '킹덤 시즌 2', '킹덤 시즌 1']}
# 40 {'배우이름': '이희준', '랭킹': 40, '흥행지수': '5592', '출연영화': ['오! 문희', '병훈의 하루', '병훈의 하루']}
# 41 {'배우이름': '라미란', '랭킹': 41, '흥행지수': '5581', '출연영화': ['나는 차였어', '정직한 후보', '막돼먹은 영애씨 시즌17']}
# 42 {'배우이름': '이봉련', '랭킹': 42, '흥행지수': '5535', '출연영화': ['날씨가 좋으면 찾아가겠어요', '엑시트', '82년생 김지영']}
# 43 {'배우이름': '고두심', '랭킹': 43, '흥행지수': '5394', '출연영화': ['동행', '엑시트', '위대한 수제자']}
# 44 {'배우이름': '장기용', '랭킹': 44, '흥행지수': '5352', '출연영화': ['본 어게인', '새콤달콤(가제)', '나쁜 녀석들: 더 무비']}

# %%
for actor in col.find({'흥행지수':{'$gte':20000}},{'_id':0,'배우이름':1,'흥행지수':1})\
.sort('배우이름',pymongo.DESCENDING):
    print(actor)

# %%
##$exists 연산자를 사용
#특기 필드가 존재하지 않ㄴ는 ㅇ경우와 존재하는 경ㅇ우 count
print(col.find({'특기':{'$exist':True}}))
print(col.find({'특기':{'$exist':False}}))
# Out:
# <pymongo.cursor.Cursor object at 0x000001DF70C357F0>
# <pymongo.cursor.Cursor object at 0x000001DF70C357C0>

# %%
criteria={'다른 이름':{'$exists':True},'다른 이름':{'$regex':'방탄소년단'}}

projection={'출연영화':{'$exists':True},'다른 이름':{'$regex':'방탄소년단'}}

# %%
#$nor연산자 not or 

print(col.count_documents({'$or':[{'흥행지수':{'$gte':15000}},{'성별':'남'}]}))
print(col.count_documents({'$nor':[{'흥행지수':{'$lte':15000}},{'성별':'여'}]}))
# Out:
# 32
# 32

# %%
criteria={'$nor':[{'흥행지수':{'$lte':15000}},{'성별':'여'}]}
print_find_document(criteria,projection)
# Out:
# 1 {'배우이름': '이병헌', '랭킹': 1, '흥행지수': '21472', '출연영화': ['비상선언', '콘크리트 유토피아', '백두산']}
# 2 {'배우이름': '진선규', '랭킹': 2, '흥행지수': '19105', '출연영화': ['카운트(가제)', '킹덤 시즌 2', '사바하']}
# 3 {'배우이름': '하정우', '랭킹': 3, '흥행지수': '17579', '출연영화': ['클로젯', '백두산', 'PMC: 더 벙커']}
# 4 {'배우이름': '마동석', '랭킹': 4, '흥행지수': '17337', '출연영화': ['시동', '나쁜 녀석들: 더 무비', '백두산']}
# 5 {'배우이름': '류승룡', '랭킹': 6, '흥행지수': '14030', '소속사': '필름있수다', '출연영화': ['휴머니멀', '킹덤 시즌 2', '입술은 안돼요(가제)']}
# 6 {'배우이름': '유해진', '랭킹': 7, '흥행지수': '13690', '소속사': '심엔터테인먼트', '출연영화': ['휴머니멀', '삼시세끼 어촌편 5', '봉오동 전투']}
# 7 {'배우이름': '박정민', '랭킹': 8, '흥행지수': '12976', '출연영화': ['사냥의 시간', '다만 악에서 구하소서', '사바하']}
# 8 {'배우이름': '황정민', '랭킹': 9, '흥행지수': '12863', '소속사': '예당엔터테인먼트', '출연영화': ['다만 악에서 구하소서', '교섭', '공작']}
# 9 {'배우이름': '송강호', '랭킹': 10, '흥행지수': '12429', '소속사': '호두엔터테인먼트', '출연영화': ['비상선언', '브로커(가제)', '기생충']}
# 10 {'배우이름': '조진웅', '랭킹': 11, '흥행지수': '11848', '소속사': '㈜사람엔터테인먼트', '출연영화': ['경관의 피(가제)', '대외비: 권력의 탄생(가제)', '광대들: 풍문조작단']}
# 11 {'배우이름': '신하균', '랭킹': 12, '흥행지수': '11173', '출연영화': ['영혼수선공', '선물', '미스터 주: 사라진 VIP']}
# 12 {'배우이름': '조우진', '랭킹': 13, '흥행지수': '10907', '출연영화': ['도굴', '서복', '봉오동 전투']}
# 13 {'배우이름': '이동휘', '랭킹': 14, '흥행지수': '10771', '출연영화': ['콜', '시네마틱드라마 SF8 -  만신', '시네마틱드라마 SF8']}
# 14 {'배우이름': '이정재', '랭킹': 15, '흥행지수': '10613', '소속사': '아티스트컴퍼니', '출연영화': ['다만 악에서 구하소서', '사바하', '보좌관 – 세상을 움직이는 사람들']}
# 15 {'배우이름': '공명', '랭킹': 18, '흥행지수': '9635', '출연영화': ['한산: 용의 출현', '행복의 진수', '행복의 진수']}
# 16 {'배우이름': '이선균', '랭킹': 20, '흥행지수': '9089', '소속사': '호두엔터테인먼트', '출연영화': ['기생충', '킹메이커', '미스터 주: 사라진 VIP']}
# 17 {'배우이름': '유아인', '랭킹': 21, '흥행지수': '8979', '출연영화': ['소리도 없이', '＃살아있다', '도올아인 오방간다']}
# 18 {'배우이름': '조정석', '랭킹': 22, '흥행지수': '8566', '출연영화': ['슬기로운 의사생활', '엑시트', '녹두꽃']}
# 19 {'배우이름': '오정세', '랭킹': 23, '흥행지수': '8377', '소속사': '스타파크엔터테인먼트', '출연영화': ['콜', '냐옹은 페이크다', '드라마 스테이지 - 남편한테 김희선이 생겼어요']}
# 20 {'배우이름': '이성민', '랭킹': 24, '흥행지수': '8338', '출연영화': ['대외비: 권력의 탄생(가제)', '머니게임', '미스터 주: 사라진 VIP']}
# 21 {'배우이름': '최우식', '랭킹': 25, '흥행지수': '8228', '출연영화': ['사냥의 시간', '경관의 피(가제)', '원더랜드']}
# 22 {'배우이름': '김윤석', '랭킹': 27, '흥행지수': '7279', '소속사': '심엔터테인먼트', '출연영화': ['바이러스(가제)', '암수살인', '미성년']}
# 23 {'배우이름': '김의성', '랭킹': 29, '흥행지수': '7163', '소속사': '아티스트컴퍼니', '출연영화': ['나의 촛불', '특송', '국민 여러분!']}
# 24 {'배우이름': '김무열', '랭킹': 31, '흥행지수': '6729', '출연영화': ['침입자', '보이스(가제)', '대외비: 권력의 탄생(가제)']}
# 25 {'배우이름': '강기영', '랭킹': 32, '흥행지수': '6558', '출연영화': ['휴가', '교섭', '런']}
# 26 {'배우이름': '곽도원', '랭킹': 33, '흥행지수': '6447', '출연영화': ['소방관', '강철비2: 정상회담', '국제수사']}
# 27 {'배우이름': '성동일', '랭킹': 34, '흥행지수': '6354', '출연영화': ['담보', '방법', '어쩌다 가족']}
# 28 {'배우이름': '김종수', '랭킹': 35, '흥행지수': '6297', '소속사': '아티스트컴퍼니', '출연영화': ['드림 (가제)', '아버지가방에들어가신다!', '삼진그룹 영어토익반']}
# 29 {'배우이름': '권해효', '랭킹': 37, '흥행지수': '5863', '출연영화': ['반도', '도망친 여자', '아무도 모른다']}
# 30 {'배우이름': '주지훈', '랭킹': 39, '흥행지수': '5685', '출연영화': ['하이에나', '킹덤 시즌 2', '킹덤 시즌 1']}
# 31 {'배우이름': '이희준', '랭킹': 40, '흥행지수': '5592', '출연영화': ['오! 문희', '병훈의 하루', '병훈의 하루']}
# 32 {'배우이름': '장기용', '랭킹': 44, '흥행지수': '5352', '출연영화': ['본 어게인', '새콤달콤(가제)', '나쁜 녀석들: 더 무비']}

# %% [markdown]
# ### list 에 포함된 문자열 검색
# *$alll 연산자에 사용하면 순서에 상관없이 값으로 해당 문자열 찾을수있씀

# %%
col.count_documents({'출연영화':'아무도 모른다'})
criteria={'출연영화':{'$all':['아무도 모른다', '특별근로감독관 조장풍']}}
print_find_document(criteria,projection)

# %%
sort={'$sortByCount':'$소속사'}

print_aggregate_document(sort)
# Out:
# [{'$sortByCount': '$소속사'}]
# {'_id': None, 'count': 27}
# {'_id': '아티스트컴퍼니', 'count': 5}
# {'_id': '호두엔터테인먼트', 'count': 3}
# {'_id': '예당엔터테인먼트', 'count': 2}
# {'_id': '심엔터테인먼트', 'count': 2}
# {'_id': 'SM엔터테인먼트', 'count': 1}
# {'_id': '㈜사람엔터테인먼트', 'count': 1}
# {'_id': 'JYP엔터테인먼트', 'count': 1}
# {'_id': '필름있수다', 'count': 1}
# {'_id': '스타파크엔터테인먼트', 'count': 1}
