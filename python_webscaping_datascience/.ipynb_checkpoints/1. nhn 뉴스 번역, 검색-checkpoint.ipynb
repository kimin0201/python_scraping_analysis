# %% [markdown]
# ##네이버 papago 서비스 사용
# 파이선 기본 urllib 라이브러리 사용

# %%
# 네이버 Papago NMT API 예제
import os
import sys
import urllib.request

client_id = "URrvC9aqM1RfBe_kqiGg"
client_secret = "HTUiqzKBPp"
encText = urllib.parse.quote("Yesterday all my troubles seemed so far away.")
data = "source=en&target=ko&text=" + encText
url = "https://openapi.naver.com/v1/papago/n2mt"
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)


response = urllib.request.urlopen(request, data=data.encode("utf-8"))


rescode = response.getcode()



if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {"message":{"@type":"response","@service":"naverservice.nmt.proxy","@version":"1.0.0","result":{"srcLangType":"en","tarLangType":"ko","translatedText":"어제 나의 모든 고민들은 너무나 멀리 떨어져 있는 것 같았다.","engineType":"N2MT","pivot":null}}}

# %%
*requests 라이브러리를 사용
# Out:
#   File "<ipython-input-57-2875dd0db8d9>", line 1
#     *requests 라이브러리를 사용
#               ^
# SyntaxError: invalid syntax

# %%
########### 업데이트

import requests 

client_id = "URrvC9aqM1RfBe_kqiGg"
client_secret = "HTUiqzKBPp"
enc_text = "Yesterday all my troubles seemed so far away."
url = "https://openapi.naver.com/v1/papago/n2mt"

#request header 값 선언 딕셔너리.키벨류값넣기
req_header = {
    "X-Naver-Client-Id":client_id, "X-Naver-Client-Secret" : client_secret 
}
#request form data 값 선언 보내고싶은데이터
req_data = {
    "source":"en",
    "target":"ko",
    "text":enc_text
}
# reqyest 보내기, post 함수 호출.
res = requests.post(url,data=req_data, headers=req_header)
print(type(res))
print(res.status_code, res.ok) #정상이면 true 가 옴
print ('응답헤더', res.headers ) #응답이 200아니면 오류난거니까 200인지확인.
print('요청헤더', res.request.headers)

if res.ok:
    print(type(res.text))
    print("응답 text", res.text)
else :
    print('status code : ', res.status_code)

# %%
if res.ok:
    result_json = res.json()
    print(type(result_json))
    print(result_json)

# %%
print(result_json['message']['result']['translatedText'])

# %%
## 네이버 검색 서비스 

import os
import sys
import urllib.request
client_id = "URrvC9aqM1RfBe_kqiGg"
client_secret = "HTUiqzKBPp"

encText = urllib.parse.quote("파이썬")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText # json 결과    #블로그까지! 
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)



response = urllib.request.urlopen(request)

rescode = response.getcode()


if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
    
    
else:
    print("Error Code:" + rescode)

# %%
import requests


def function(keyword,displaycount):

    
    #keyword="갤럭시"
    client_id = "URrvC9aqM1RfBe_kqiGg"
    client_secret = "HTUiqzKBPp"

    url = "https://openapi.naver.com/v1/search/blog"

    req_header = {
        "X-Naver-Client-Id":client_id, 
        "X-Naver-Client-Secret" : client_secret 
    }
    # 쿼리해결. 데이터를 보내고싶ㄸ ㅏ
    #request form data 값 선언 보내고싶은데이터 요청데이타
    req_data = {
        "query":keyword
        "display":displaycount
        
    }



    res = requests.get(url, params=req_data, headers=req_header)

    print(res.status_code, res.ok)
    print(res.text) #데이터 가져옴
    
    #print(res.text)
    json_data = res.json()
    print(type(json_data['items']))
    item_list = json_data['items']
    print(len(item_list))
    for item in item_list:
        print(item)
    
    
    

   
function("파이선",2)

# %%
import requests


def function(keyword):


    #keyword="갤럭시"
    client_id = "URrvC9aqM1RfBe_kqiGg"
    client_secret = "HTUiqzKBPp"

    url = "https://openapi.naver.com/v1/search/blog"

    req_header = {
        "X-Naver-Client-Id":client_id, 
        "X-Naver-Client-Secret" : client_secret 
    }
    # 쿼리해결. 데이터를 보내고싶ㄸ ㅏ
    #request form data 값 선언 보내고싶은데이터
    req_data = {
        "query":keyword
    }



    res = requests.get(url, params=req_data, headers=req_header)

    print(res.status_code, res.ok)
    print(res.text) #데이터 가져옴


function("자바")

# %%
import requests


def function(keyword,displaycount):

    
    #keyword="갤럭시"
    client_id = "URrvC9aqM1RfBe_kqiGg"
    client_secret = "HTUiqzKBPp"

    url = "https://openapi.naver.com/v1/search/blog"

    req_header = {
        "X-Naver-Client-Id":client_id, 
        "X-Naver-Client-Secret" : client_secret 
    }
    # 쿼리해결. 데이터를 보내고싶ㄸ ㅏ
    #request form data 값 선언 보내고싶은데이터 요청데이타
    req_data = {
        "query":keyword,
        "display":displaycount
        
    }



    res = requests.get(url, params=req_data, headers=req_header)

    #print(res.status_code, res.ok)
    print(res.text) #데이터 가져옴
    
    result_list = []
    #print(res.text)
    json_data = res.json()
    #print(type(json_data['items']))
    item_list = json_data['items']
    #print(len(item_list))
    for item in item_list:
        #print(item)
        result_list.append(item)
    return result_list
    
    
    

   
function("파이선",2)

# %%
my_list = function("파이선",2)
print(my_list)

# %%
import requests


def function(keyword,kind,displaycount):

    
    #keyword="갤럭시"
    client_id = "URrvC9aqM1RfBe_kqiGg"
    client_secret = "HTUiqzKBPp"

    url = f"https://openapi.naver.com/v1/search/{kind}.json"

    req_header = {
        "X-Naver-Client-Id":client_id, 
        "X-Naver-Client-Secret" : client_secret 
    }
    # 쿼리해결. 데이터를 보내고싶ㄸ ㅏ
    #request form data 값 선언 보내고싶은데이터 요청데이타
    req_data = {
        "query":keyword,
        "display":displaycount
        
    }



    res = requests.get(url, params=req_data, headers=req_header)

    #print(res.status_code, res.ok)
    print(res.text) #데이터 가져옴
    
    result_list = []
    #print(res.text)
    json_data = res.json()
    #print(type(json_data['items']))
    #item_list = json_data['items']
    #print(len(item_list))
    item_list = []
    for item in item_list:
        #print(item)
        result_list.append(item)
    return result_list
    
    
    

   
#result_list = function("슈퍼콘",'blog',2)
#print(result_list)

# %%
def my_url(kind):
    url = f"https://openapi.naver.con/v1/search/{kind}.json"
    print(url)
    
my_url('news')
# Out:
# https://openapi.naver.con/v1/search/news.json

# %%
result_list = function('딥러닝',kind,2):
for result in result_list:
    print(result)
# Out:
#   File "<ipython-input-64-34b8530824e0>", line 1
#     result_list = function('딥러닝',kind,2):
#                                         ^
# SyntaxError: invalid syntax

# %%
kind_list = ['blog','book','news']
for kind in kind_list:
    print(f'>>> 분야 : {kind}')
    for item in function('딥러닝',kind,2):
        print(item)
# Out:
# >>> 분야 : blog
# {
# "lastBuildDate": "Fri, 16 Oct 2020 12:06:23 +0900",
# "total": 92180,
# "start": 1,
# "display": 2,
# "items": [
# {
# "title": "인공지능(<b>딥러닝</b>)의 정의와 사례",
# "link": "https:\/\/blog.naver.com\/infopub?Redirect=Log&logNo=222114155013",
# "description": "이에는 머신러닝, <b>딥러닝</b>이 모두 포함돼 있습니다. 그중에서도 우리는 인공지능의 획기적인 발전을 이끈 <b>딥러닝</b>에 대해 자세히 알아보겠습니다. 또한 <b>딥러닝</b>은 무엇이고 그 종류에는 어떤 것이... ",
# "bloggername": "IT 서적의 명가",
# "bloggerlink": "https://blog.naver.com/infopub",
# "postdate": "20201013"
#
# },
# {
# "title": "이해 #1 – 주요 역사와 개념 정리(feat. 머신러닝, <b>딥러닝</b>)",
# "link": "https:\/\/blog.naver.com\/skinfosec2000?Redirect=Log&logNo=222029239340",
# "description": "오늘은 4차 산업혁명 시대의 핵심 기술이라 불리는 인공지능의 주요 역사와 특징 그리고 머신러닝과 <b>딥러닝</b>의 차이에 대해 알아보겠습니다. ‘인공지능(AI, Artificial Intelligence)’이란? 인공지능은... ",
# "bloggername": "SK인포섹(주) 공식블로그",
# "bloggerlink": "https://blog.naver.com/skinfosec2000",
# "postdate": "20200713"
#
# }
# ]
# }
#
# >>> 분야 : book
# {
# "lastBuildDate": "Fri, 16 Oct 2020 12:06:23 +0900",
# "total": 834,
# "start": 1,
# "display": 2,
# "items": [
# {
# "title": "모두의 <b>딥러닝</b>(개정판 2판) (자연어 처리, GAN, 오토인코더, 전이 학습 등으로 나만의 모델을 만든다 with 텐서플로2.0 & 케라스)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=16215446",
# "image": "https://bookthumb-phinf.pstatic.net/cover/162/154/16215446.jpg?type=m1&udate=20200825",
# "author": "조태호",
# "price": "24000",
# "discount": "21600",
# "publisher": "길벗",
# "pubdate": "20200127",
# "isbn": "1165210398 9791165210397",
# "description": "<b>딥러닝</b> 기초부터 최신 트렌드까지 한 권으로 공부하자\n그동안 <b>딥러닝</b> 입문서로 제 역할을 톡톡히 해낸 『모두의 <b>딥러닝</b>』이 최근 주목받는 주제들을 담아 기존 내용을 보강하여 개정 2판으로 돌아왔다. 초판에서 다루지 않았던 GAN, 오토인코더, 자연어 처리, 전이 학습 등 새로운 내용을 수록하였고, <b>딥러닝</b>을... "
#
# },
# {
# "title": "밑바닥부터 시작하는 <b>딥러닝</b> 2 (파이썬으로 직접 구현하며 배우는 순환 신경망과 자연어 처리)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=14797086",
# "image": "https://bookthumb-phinf.pstatic.net/cover/147/970/14797086.jpg?type=m1&udate=20200423",
# "author": "사이토 고키",
# "price": "29000",
# "discount": "26100",
# "publisher": "한빛미디어",
# "pubdate": "20190501",
# "isbn": "1162241748 9791162241745",
# "description": "직접 구현하면서 배우는 본격 <b>딥러닝</b> 입문서\n이번에는 순환 신경망과 자연어 처리다!이 책은 『밑바닥부터 시작하는 <b>딥러닝</b>』에서 다루지 못했던 순환 신경망(RNN)을 자연어 처리와 시계열 데이터 처리에 사용하는 <b>딥러닝</b> 기술에 초점을 맞춰 살펴본다. 8장 구성으로 전체를 하나의 이야기처럼 순서대로 읽도록... "
#
# }
# ]
# }
#
# >>> 분야 : news
# {
# "lastBuildDate": "Fri, 16 Oct 2020 12:06:24 +0900",
# "total": 73227,
# "start": 1,
# "display": 2,
# "items": [
# {
# "title": "㈜민트토이 '자체 3D 애니' 콘텐츠 개발…전남 강소기업 도약",
# "originallink": "http://www.newsis.com/view/?id=NISX20201016_0001200036&cID=13001&pID=13000",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=003&aid=0010130244",
# "description": "분야에선 <b>딥러닝</b>(스스로 학습하는 컴퓨터)을 이용한 어플 '셀피토이(Selfie Toy)'를 개발하는데 성공해 기술력과 전문성을 입증 받았다. 이 프로그램은 전용 웹페이지에 얼굴 사진을 올리면 <b>딥러닝</b>이 얼굴 인식을 통해... ",
# "pubDate": "Fri, 16 Oct 2020 11:51:00 +0900"
#
# },
# {
# "title": "삼성메디슨, ISUOG서 ‘인텔리전트 어시스트’ 솔루션 소개",
# "originallink": "http://www.bokuennews.com/news/article.html?no=195942",
# "link": "http://www.bokuennews.com/news/article.html?no=195942",
# "description": "특히 하트어시스트는 선천성 심장 질환을 <b>딥러닝</b> 방식을 적용해 빠르고 정확하게 자동 측정해 주는 것으로, 올 6월 의료영상분석장치 소프트웨어 2등급을 획득해 삼성메디슨 최초 AI 의료기기로 허가 받은... ",
# "pubDate": "Fri, 16 Oct 2020 11:47:00 +0900"
#
# }
# ]
# }

# %% [markdown]
# ##파파고 서비스 사용😏😉
# *yesterday.txt 가사 파일의 내용을 읽어서 list에 저장
# *list에 있는 내용으 ㄹ번역 서비스 요청
# *서비스 응답 결과를 다시 파일에 저장

# %%
import requests


def translyric_savefile(trans_list):
    with open('data/yesterday_trans.txt','w',encoding='utf8') as file :
        file.writelines(trans_list)



#esterday.txt 가사 파일의 내용을 읽어서 list에 저장
def gettext_savelist():
    lyric_list = []
    with open('data/yesterday.txt','r',encoding='utf8') as file:
        contents = file.read()
        print(contents) #파일을 읽었다~!
        print()
        print(type(contents))
        lyric_list=contents.split('\n')
        
    return lyric_list




def main():
    client_id = "URrvC9aqM1RfBe_kqiGg"
    client_secret = "HTUiqzKBPp"
    
    url = "https://openapi.naver.com/v1/papago/n2mt"

        
        
    req_header = {
        "X-Naver-Client-Id":client_id, 
        "X-Naver-Client-Secret" : client_secret 
    }
    
    lyric_list = gettext_savelist()
    lyric_list = [lyric for lyric in lyric_list if len(lyric) != 0 ] #가사없는거 떨구려고 
    print(len(lyric_list))
    
    trans_list =[]
    
    print('>>>>>>번역시작 ! !')
    
    for req_lyric in lyric_list:
        print(req_lyric)
        req_data = {
        "source":"en",
        "target":"ko",
        "text":req_lyric
        }
        #파피고 서비스 요청, post()함수 호출
        
        res = requests.post(url,data=req_data, headers=req_header)
        print(res.status_code)
        # print(req_lyric)
        # 쿼리해결. 데이터를 보내고싶ㄸ ㅣ 보내고 싶은 데이터. 
        
        #jsone함수#모지?
        try:
            trans_lyric = res.json()['message'][ 'result'] ['translatedText']
        except Exception as exp:
            print(res.status_code)
        else:
            print(trans_lyric)
            
        trans_list.append(req_lyric+ '\n')
        trans_list.append(trans_lyric + '\n')
        
    #print(trans_list)
    translyric_savefile(trans_list) #이걸 인자를 던진다구 표현하신다!! 인자를 던져!
    print('>>>>>>번역 종료 ! 1 !')
    
    
    
    

main()

# %%
import requests


def translyric_savefile(trans_list):
    with open('data/poppin_trans.txt','w',encoding='utf8') as file :
        file.writelines(trans_list)



#esterday.txt 가사 파일의 내용을 읽어서 list에 저장
def gettext_savelist():
    lyric_list = []
    with open('data/poppin.txt','r',encoding='utf8') as file:
        contents = file.read()
        print(contents) #파일을 읽었다~!
        print()
        print(type(contents))
        lyric_list=contents.split('\n')
        
    return lyric_list




def main():
    client_id = "URrvC9aqM1RfBe_kqiGg"
    client_secret = "HTUiqzKBPp"
    
    url = "https://openapi.naver.com/v1/papago/n2mt"

        
        
    req_header = {
        "X-Naver-Client-Id":client_id, 
        "X-Naver-Client-Secret" : client_secret 
    }
    
    lyric_list = gettext_savelist()
    lyric_list = [lyric for lyric in lyric_list if len(lyric) != 0 ] #가사없는거 떨구려고 
    print(len(lyric_list))
    
    trans_list =[]
    
    print('>>>>>>번역시작 ! !')
    
    for req_lyric in lyric_list:
        print(req_lyric)
        req_data = {
        "source":"ko",
        "target":"en",
        "text":req_lyric
        }
        #파피고 서비스 요청, post()함수 호출
        
        res = requests.post(url,data=req_data, headers=req_header)
        print(res.status_code)
        # print(req_lyric)
        # 쿼리해결. 데이터를 보내고싶ㄸ ㅣ 보내고 싶은 데이터. 
        
        #jsone함수#모지?
        try:
            trans_lyric = res.json()['message'][ 'result'] ['translatedText']
        except Exception as exp:
            print(res.status_code)
        else:
            print(trans_lyric)
            
        trans_list.append(req_lyric+ '\n')
        trans_list.append(trans_lyric + '\n')
        
    #print(trans_list)
    translyric_savefile(trans_list) #이걸 인자를 던진다구 표현하신다!! 인자를 던져!
    print('>>>>>>번역 종료 ! 1 !')
    
    
    
    

main()

# %%
import requests


def translyric_savefile(trans_list,lyric_out):
    with open(f'data/{lyric_out}_trans.txt','w',encoding='utf8') as file :
        file.writelines(trans_list)



#esterday.txt 가사 파일의 내용을 읽어서 list에 저장
def gettext_savelist(lyric_in):
    
    lyric_list = []
    with open(f'data/{lyric_in}.txt','r',encoding='utf8') as file:
        contents = file.read()
        print(contents) #파일을 읽었다~!
        print()
        print(type(contents))
        lyric_list=contents.split('\n')
        
    return lyric_list




def main(lyric_in,lyric_out):
    client_id = "URrvC9aqM1RfBe_kqiGg"
    client_secret = "HTUiqzKBPp"
    
    url = "https://openapi.naver.com/v1/papago/n2mt"

        
        
    req_header = {
        "X-Naver-Client-Id":client_id, 
        "X-Naver-Client-Secret" : client_secret 
    }
    
    lyric_list = gettext_savelist(lyric_in)
    lyric_list = [lyric for lyric in lyric_list if len(lyric) != 0 ] #가사없는거 떨구려고 
    print(len(lyric_list))
    
    trans_list =[]
    
    print('>>>>>>번역시작 ! !')
    
    for req_lyric in lyric_list:
        print(req_lyric)
        req_data = {
        "source":"ko",
        "target":"en",
        "text":req_lyric
        }
        #파피고 서비스 요청, post()함수 호출
        
        res = requests.post(url,data=req_data, headers=req_header)
        print(res.status_code)
        # print(req_lyric)
        # 쿼리해결. 데이터를 보내고싶ㄸ ㅣ 보내고 싶은 데이터. 
        
        #jsone함수#모지?
        try:
            trans_lyric = res.json()['message'][ 'result'] ['translatedText']
        except Exception as exp:
            print(res.status_code)
        else:
            print(trans_lyric)
            
        trans_list.append(req_lyric+ '\n')
        trans_list.append(trans_lyric + '\n')
        
    #print(trans_list)
    translyric_savefile(trans_list,lyric_out) #이걸 인자를 던진다구 표현하신다!! 인자를 던져!
    print('>>>>>>번역 종료 ! 1 !')
    
    
    
    

main('poppin','poppin')
# Out:
# 너는 들을수록
# 자꾸 좋아지는 노래
# 보고 또 봐도 귀여운
# 사랑스런 영화 같은데
# 커플들의 클리셰
# 편해진 사이는 너무 위험해
# Oh no 그런 얘기
# 내겐 좀 시시한 소리 같아
#
# Oh my 더 반짝이는 너
# Girl I know
# what you wanna do, wanna do
# 얼마만큼의 시간 흘러가야만
# 사랑인 걸까?
# 나를 믿고 와
# We’re about to change our lives
#
#
# <class 'str'>
# 15
# >>>>>>번역시작 ! !
# 너는 들을수록
# 200
# The more you listen,
# 자꾸 좋아지는 노래
# 200
# a song that keeps getting better
# 보고 또 봐도 귀여운
# 200
# Cute to see and see
# 사랑스런 영화 같은데
# 200
# Sounds like a lovely movie.
# 커플들의 클리셰
# 200
# couple's cliche
# 편해진 사이는 너무 위험해
# 200
# It's too dangerous to be comfortable.
# Oh no 그런 얘기
# 200
# Oh no, that's what I'm talking about.
# 내겐 좀 시시한 소리 같아
# 200
# I think it's a little lame for me.
# Oh my 더 반짝이는 너
# 200
# Oh my more shiny you
# Girl I know
# 200
# Girl I know
# what you wanna do, wanna do
# 200
# What you wanna do, wanna do
# 얼마만큼의 시간 흘러가야만
# 200
# How much time has to pass
# 사랑인 걸까?
# 200
# Is it love?
# 나를 믿고 와
# 200
# Trust me.
# We’re about to change our lives
# 200
# We're about to change our lives
# >>>>>>번역 종료 ! 1 !

# %%
import requests


def translyric_savefile(trans_list,lyric_out):
    with open(f'data/{lyric_out}_trans.txt','w',encoding='utf8') as file :
        file.writelines(trans_list)

#오류읽어서수정하는거..신기하ㅗ잼다

#esterday.txt 가사 파일의 내용을 읽어서 list에 저장
def gettext_savelist(lyric_in):
    
    lyric_list = []
    with open(f'data/{lyric_in}.txt','r',encoding='utf8') as file:
        contents = file.read()
        print(contents) #파일을 읽었다~!
        print()
        print(type(contents))
        lyric_list=contents.split('\n')
        
    return lyric_list




def main(lyric_in,lyric_out):
    client_id = "URrvC9aqM1RfBe_kqiGg"
    client_secret = "HTUiqzKBPp"
    
    url = "https://openapi.naver.com/v1/papago/n2mt"

        
        
    req_header = {
        "X-Naver-Client-Id":client_id, 
        "X-Naver-Client-Secret" : client_secret 
    }
    
    lyric_list = gettext_savelist(lyric_in)
    lyric_list = [lyric for lyric in lyric_list if len(lyric) != 0 ] #가사없는거 떨구려고 
    print(len(lyric_list))
    
    trans_list =[]
    
    print('>>>>>>번역시작 ! !')
    
    for req_lyric in lyric_list:
        print(req_lyric)
        req_data = {
        "source":"ko",
        "target":"en",
        "text":req_lyric
        }
        #파피고 서비스 요청, post()함수 호출
        
        res = requests.post(url,data=req_data, headers=req_header)
        print(res.status_code)
        # print(req_lyric)
        # 쿼리해결. 데이터를 보내고싶ㄸ ㅣ 보내고 싶은 데이터. 
        
        #jsone함수#모지?
        try:
            trans_lyric = res.json()['message'][ 'result'] ['translatedText']
        except Exception as exp:
            print(res.status_code)
        else:
            print(trans_lyric)
            
        trans_list.append(req_lyric+ '\n')
        trans_list.append(trans_lyric + '\n')
        
    #print(trans_list)
    translyric_savefile(trans_list,lyric_out) #이걸 인자를 던진다구 표현하신다!! 인자를 던져!
    print('>>>>>>번역 종료 ! 1 !')
    
    
    
    

main('너를 사랑하고 있어','너를 사랑하고 있어')
# Out:
# 어떤 말로 표현해야 이 감정을 알까
#
# 어떻게 널 바라봐야 나의 마음을 알까
#
# 너와 같이 계절을 겪고 너와 거리를 걷고
#
# 아주 천천히 너를 알아가는 이 시간 속에
#
#
#
# 네가 어디 있다 해도
#
# 너를 사랑하고 있어
#
# 서두르지 않을게 난
#
# 네 뒤에 서 너를 지켜줄게
#
# <class 'str'>
# 8
# >>>>>>번역시작 ! !
# 어떤 말로 표현해야 이 감정을 알까
# 200
# How do I put this feeling?
# 어떻게 널 바라봐야 나의 마음을 알까
# 200
# How can I look at you to know how I feel?
# 너와 같이 계절을 겪고 너와 거리를 걷고
# 200
# I walk through the season with you and walk the streets with you.
# 아주 천천히 너를 알아가는 이 시간 속에
# 200
# In this time of getting to know you very slowly,
# 네가 어디 있다 해도
# 200
# Wherever you are,
# 너를 사랑하고 있어
# 200
# I'm in love with you.
# 서두르지 않을게 난
# 200
# I'm not in a hurry.
# 네 뒤에 서 너를 지켜줄게
# 200
# I'll stand behind you and protect you.
# >>>>>>번역 종료 ! 1 !

# %%
import requests


def translyric_savefile(trans_list,lyric_in):
    with open(f'data/{lyric_in}_trans.txt','w',encoding='utf8') as file :
        file.writelines(trans_list)



#esterday.txt 가사 파일의 내용을 읽어서 list에 저장
def gettext_savelist(lyric_in):
    
    lyric_list = []
    with open(f'data/{lyric_in}.txt','r',encoding='utf8') as file:
        contents = file.read()
        print(contents) #파일을 읽었다~!
        print()
        print(type(contents))
        lyric_list=contents.split('\n')
        
    return lyric_list




def main(lyric_in):
    client_id = "URrvC9aqM1RfBe_kqiGg"
    client_secret = "HTUiqzKBPp"
    
    url = "https://openapi.naver.com/v1/papago/n2mt"

        
        
    req_header = {
        "X-Naver-Client-Id":client_id, 
        "X-Naver-Client-Secret" : client_secret 
    }
    
    lyric_list = gettext_savelist(lyric_in)
    lyric_list = [lyric for lyric in lyric_list if len(lyric) != 0 ] #가사없는거 떨구려고 
    print(len(lyric_list))
    
    trans_list =[]
    
    print('>>>>>>번역시작 ! !')
    
    for req_lyric in lyric_list:
        print(req_lyric)
        req_data = {
        "source":"ko",
        "target":"en",
        "text":req_lyric
        }
        #파피고 서비스 요청, post()함수 호출
        
        res = requests.post(url,data=req_data, headers=req_header)
        print(res.status_code)
        # print(req_lyric)
        # 쿼리해결. 데이터를 보내고싶ㄸ ㅣ 보내고 싶은 데이터. 
        
        #jsone함수#모지?
        try:
            trans_lyric = res.json()['message'][ 'result'] ['translatedText']
        except Exception as exp:
            print(res.status_code)
        else:
            print(trans_lyric)
            
        trans_list.append(req_lyric+ '\n')
        trans_list.append(trans_lyric + '\n')
        
    #print(trans_list)
    translyric_savefile(trans_list,lyric_in) #이걸 인자를 던진다구 표현하신다!! 인자를 던져!
    print('>>>>>>번역 종료 ! 1 !')
    
    
    
    
lyric_in=input()
main(lyric_in)

# %%
import requests


def translyric_savefile(trans_list,lyric_in):
    with open(f'data/{lyric_in}_trans.txt','w',encoding='utf8') as file :
        file.writelines(trans_list)



#esterday.txt 가사 파일의 내용을 읽어서 list에 저장
def gettext_savelist(lyric_in):
    
    lyric_list = []
    with open(f'data/{lyric_in}.txt','r',encoding='utf8') as file:
        contents = file.read()
        print(contents) #파일을 읽었다~!
        print()
        print(type(contents))
        lyric_list=contents.split('\n')
        
    return lyric_list




def main(lyric_in):
    client_id = "URrvC9aqM1RfBe_kqiGg"
    client_secret = "HTUiqzKBPp"
    
    url = "https://openapi.naver.com/v1/papago/n2mt"

        
        
    req_header = {
        "X-Naver-Client-Id":client_id, 
        "X-Naver-Client-Secret" : client_secret 
    }
    
    lyric_list = gettext_savelist(lyric_in)
    lyric_list = [lyric for lyric in lyric_list if len(lyric) != 0 ] #가사없는거 떨구려고 
    print(len(lyric_list))
    
    trans_list =[]
    
    print('>>>>>>번역시작 ! !')
    
    for req_lyric in lyric_list:
        print(req_lyric)
        req_data = {
        "source":"ko",
        "target":"en",
        "text":req_lyric
        }
        #파피고 서비스 요청, post()함수 호출
        
        res = requests.post(url,data=req_data, headers=req_header)
        print(res.status_code)
        # print(req_lyric)
        # 쿼리해결. 데이터를 보내고싶ㄸ ㅣ 보내고 싶은 데이터. 
        
        #jsone함수#모지?
        try:
            trans_lyric = res.json()['message'][ 'result'] ['translatedText']
        except Exception as exp:
            print(res.status_code)
        else:
            print(trans_lyric)
            
        trans_list.append(req_lyric+ '\n')
        trans_list.append(trans_lyric + '\n')
        
    #print(trans_list)
    translyric_savefile(trans_list,lyric_in) #이걸 인자를 던진다구 표현하신다!! 인자를 던져!
    print('>>>>>>번역 종료 ! 1 !')
    
    
    
    
lyric_in=input()
main(lyric_in)
#인풋으로만으로두 되네~~~
